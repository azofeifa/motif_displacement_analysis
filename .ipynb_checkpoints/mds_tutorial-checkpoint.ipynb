# %% [markdown]
# # Introduction
#
# This notebook is meant to supplement the publication "Enhanancer RNA expression predicts TF activity." In brief, our group analyzed 494 and 273 human/mouse nascent transcript datasets and integrated 641 TF binding motifs. Becuase of the volume of data, we were unable to explore every possible comparison, cell type or treatment. With this in mind, the notebook will allow the user to explore experimental meta data, bidirectional transript predictions and integrated motif analysis.

# %%
'''
    These are the required libraries/modules
    obviously if you can't run this cell then the rest of the notebook will fail
'''
import numpy as np
import scipy.stats as ss
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from statsmodels.stats import multitest
from MDAP.experiment import dataset
from MDAP.md_stats import mds_frame



sns.set_style("white")
# %matplotlib inline

# %%
'''
    This .csv file contains all the meta data associated with each
    dataset. These easiest way to traverse this data is to use
    the pandas dataframe
    
    Below are a couple of examples demsontrating use of a pandas dataframe
    if you are new to pandas, you might find these useful:
    
    http://pandas.pydata.org
'''

conditions_table="./conditions_table.csv"
ct=pd.read_csv(conditions_table)

'''
    Retrieve all the "human" datasets
'''
human=ct[ct.organism=="human"].SRAnumber

'''
    Retrieve all the "human" datasets that are also are myeloid samples
'''
human_blood=ct[(ct.organism=="human") & (ct.tissue=="Myeloid") ].SRAnumber

# %%
'''
    The directory of motif displacement files. If you downloaded the tar ball from the "Enhanancer RNA expression 
    predicts TF activity."please chane accordingly. The default setting assumes you are running this notebook 
    within the motif_displacement_analysis
    cloned from git.
    
    Each file is uniquely name the SRA number and corresponds exactly to conditions_table.csv
'''

MDS_DIR = "./motif_displacement_files/"

# %%
# %matplotlib inline
sns.set_style("white")



'''
    Lets start by just looking at the motif displacement of specific motif of a specific dataset. For this,
    you will use to experiment.dataset class
'''
d = dataset(MDS_DIR+"SRR1552480" + ".csv")
'''
    So now that we have loaded this dataset we can call a few methods
'''
F  = plt.figure(figsize=(15,10))
ax = plt.gca()
'''
    Note that if you run this module outside the jupyer framework you will need to call plt.show()
'''
d.show_motif_displacement(Spec="HO_NRF1_HUMAN.H10MO.A",ax=ax,as_histogram=True)

# %%
'''
    so that's kinda cool but it takes up a lot of page space!
'''
F  = plt.figure(figsize=(15,2))
ax = plt.gca()
d.show_motif_displacement(Spec="HO_NRF1_HUMAN.H10MO.A",ax=ax,as_histogram=False)

# %%
'''
    well okay, this is fine but are we going to do this for ALL 641 motifs?
'''


F  = plt.figure(figsize=(10,10))
ax1 = F.add_subplot(1,2,1)
ax2 = F.add_subplot(1,2,2)

motif_order = d.show_motif_displacement(All=True,ax=ax1)

'''
    obviously, placing show_histogram=True while All is turned on won't do anything!
'''

'''
    could we change the colormap?
'''
import matplotlib.cm as cm
cmap = cm.jet #maybe not this one! 
motifs = d.show_motif_displacement(All=True,ax=ax2,as_histogram=False,cmap=cmap)

# %%
'''
what about ordering the rows?

1) either by hierarchical ward clustering of the normalized rows 
2) or 2, by MD score
'''
F  = plt.figure(figsize=(10,10))
ax1 = F.add_subplot(1,2,1)
ax2 = F.add_subplot(1,2,2)
ax1.set_title("By MD Score")
motif_order = d.show_motif_displacement(All=True,ax=ax1,sort_md=True)

ax2.set_title("Hierarchical Ward")
motif_order = d.show_motif_displacement(All=True,ax=ax2,clustering=True)
print motif_order
# Out:
# ['HO_ZBED1_HUMAN.H10MO.D' 'HO_E2F2_HUMAN.H10MO.B' 'HO_HINFP_HUMAN.H10MO.C'
#  'HO_MUSC_HUMAN.H10MO.D' 'HO_CENPB_HUMAN.H10MO.D' 'HO_NR2C2_HUMAN.H10MO.A'
#  'HO_COT2_HUMAN.H10MO.S' 'HO_COT2_HUMAN.H10MO.A' 'HO_NKX23_HUMAN.H10MO.D'
#  'HO_COT1_HUMAN.H10MO.S' 'HO_PPARA_HUMAN.H10MO.C' 'HO_VDR_HUMAN.H10MO.B'
#  'HO_TGIF1_HUMAN.H10MO.D' 'HO_ESR2_HUMAN.H10MO.A' 'HO_PAX1_HUMAN.H10MO.D'
#  'HO_PPARG_HUMAN.H10MO.A' 'HO_GLIS2_HUMAN.H10MO.D' 'HO_ZN410_HUMAN.H10MO.D'
#  'HO_GRHL1_HUMAN.H10MO.D' 'HO_PO3F1_HUMAN.H10MO.C' 'HO_TYY1_HUMAN.H10MO.A'
#  'HO_MYBA_HUMAN.H10MO.D' 'HO_ZBT7A_HUMAN.H10MO.D' 'HO_SMAD4_HUMAN.H10MO.C'
#  'HO_SMAD2_HUMAN.H10MO.C' 'HO_SP1_HUMAN.H10MO.S' 'HO_ETV6_HUMAN.H10MO.D'
#  'HO_FOXF2_HUMAN.H10MO.D' 'HO_ATF2_HUMAN.H10MO.B' 'HO_ATF1_HUMAN.H10MO.B'
#  'HO_KLF4_HUMAN.H10MO.A' 'HO_CEBPZ_HUMAN.H10MO.D' 'HO_FOSB_HUMAN.H10MO.C'
#  'HO_FOSL1_HUMAN.H10MO.A' 'HO_FOSL2_HUMAN.H10MO.A' 'HO_USF1_HUMAN.H10MO.A'
#  'HO_JUN_HUMAN.H10MO.A' 'HO_ELK1_HUMAN.H10MO.A' 'HO_GATA6_HUMAN.H10MO.B'
#  'HO_STAT1_HUMAN.H10MO.S' 'HO_STAT1_HUMAN.H10MO.A' 'HO_YBOX1_HUMAN.H10MO.D'
#  'HO_BATF_HUMAN.H10MO.S' 'HO_SMRC1_HUMAN.H10MO.D' 'HO_ELK4_HUMAN.H10MO.A'
#  'HO_ERG_HUMAN.H10MO.B' 'HO_CREB1_HUMAN.H10MO.A' 'HO_FOXC2_HUMAN.H10MO.D'
#  'HO_ATF3_HUMAN.H10MO.A' 'HO_BMAL1_HUMAN.H10MO.C' 'HO_SP3_HUMAN.H10MO.B'
#  'HO_SP2_HUMAN.H10MO.C' 'HO_GABPA_HUMAN.H10MO.A' 'HO_EGR1_HUMAN.H10MO.S'
#  'HO_SP4_HUMAN.H10MO.D' 'HO_SP1_HUMAN.H10MO.C' 'HO_TFEB_HUMAN.H10MO.C'
#  'HO_FOS_HUMAN.H10MO.A' 'HO_JUNB_HUMAN.H10MO.C' 'HO_E4F1_HUMAN.H10MO.D'
#  'HO_E2F5_HUMAN.H10MO.B' 'HO_E2F3_HUMAN.H10MO.B' 'HO_CREB3_HUMAN.H10MO.D'
#  'HO_JDP2_HUMAN.H10MO.D' 'HO_ATF7_HUMAN.H10MO.D' 'HO_CREB5_HUMAN.H10MO.D'
#  'HO_PBX3_HUMAN.H10MO.B' 'HO_USF2_HUMAN.H10MO.A' 'HO_NF2L2_HUMAN.H10MO.D'
#  'HO_JUND_HUMAN.H10MO.A' 'HO_EGR4_HUMAN.H10MO.D' 'HO_ZN639_HUMAN.H10MO.D'
#  'HO_NFYC_HUMAN.H10MO.B' 'HO_FOXI1_HUMAN.H10MO.B' 'HO_NFYB_HUMAN.H10MO.A'
#  'HO_BACH1_HUMAN.H10MO.A' 'HO_NRF1_HUMAN.H10MO.A' 'HO_KAISO_HUMAN.H10MO.A'
#  'HO_NFE2_HUMAN.H10MO.B' 'HO_CTCF_HUMAN.H10MO.A' 'HO_CTCFL_HUMAN.H10MO.A'
#  'HO_NFYA_HUMAN.H10MO.A' 'HO_MAFK_HUMAN.H10MO.S' 'HO_FOXD1_HUMAN.H10MO.D'
#  'HO_FOXC1_HUMAN.H10MO.C' 'HO_TAL1_HUMAN.H10MO.A' 'HO_GATA1_HUMAN.H10MO.A'
#  'HO_ZN589_HUMAN.H10MO.D' 'HO_ESR1_HUMAN.H10MO.S' 'HO_RHXF1_HUMAN.H10MO.D'
#  'HO_GSC_HUMAN.H10MO.D' 'HO_ZSCA4_HUMAN.H10MO.D' 'HO_ZN350_HUMAN.H10MO.C'
#  'HO_HXA9_HUMAN.H10MO.D' 'HO_INSM1_HUMAN.H10MO.C' 'HO_ZBTB6_HUMAN.H10MO.D'
#  'HO_HEN1_HUMAN.H10MO.C' 'HO_MLXPL_HUMAN.H10MO.D' 'HO_RXRG_HUMAN.H10MO.B'
#  'HO_FOXK1_HUMAN.H10MO.D' 'HO_NDF2_HUMAN.H10MO.D' 'HO_BATF3_HUMAN.H10MO.D'
#  'HO_TF2LX_HUMAN.H10MO.D' 'HO_MEF2B_HUMAN.H10MO.D' 'HO_RFX1_HUMAN.H10MO.C'
#  'HO_EVI1_HUMAN.H10MO.B' 'HO_HXC11_HUMAN.H10MO.D' 'HO_COT1_HUMAN.H10MO.B'
#  'HO_VAX2_HUMAN.H10MO.D' 'HO_ZBT18_HUMAN.H10MO.D' 'HO_NFAC1_HUMAN.H10MO.S'
#  'HO_ZEP1_HUMAN.H10MO.D' 'HO_SPDEF_HUMAN.H10MO.D' 'HO_ZEP2_HUMAN.H10MO.D'
#  'HO_EGR3_HUMAN.H10MO.D' 'HO_TAL1_HUMAN.H10MO.S' 'HO_NR2C1_HUMAN.H10MO.C'
#  'HO_RARG_HUMAN.H10MO.C' 'HO_PAX8_HUMAN.H10MO.D' 'HO_ZN282_HUMAN.H10MO.D'
#  'HO_VSX2_HUMAN.H10MO.D' 'HO_MAX_HUMAN.H10MO.A' 'HO_MAFB_HUMAN.H10MO.D'
#  'HO_PLAL1_HUMAN.H10MO.D' 'HO_THB_HUMAN.H10MO.S' 'HO_ZBT49_HUMAN.H10MO.D'
#  'HO_ARNT2_HUMAN.H10MO.D' 'HO_MYC_HUMAN.H10MO.A' 'HO_HIC1_HUMAN.H10MO.C'
#  'HO_HESX1_HUMAN.H10MO.D' 'HO_P63_HUMAN.H10MO.A' 'HO_MEIS1_HUMAN.H10MO.C'
#  'HO_ZBTB4_HUMAN.H10MO.D' 'HO_RARA_HUMAN.H10MO.C' 'HO_PO6F1_HUMAN.H10MO.D'
#  'HO_SOX1_HUMAN.H10MO.D' 'HO_HXA7_HUMAN.H10MO.D' 'HO_ZN333_HUMAN.H10MO.D'
#  'HO_NFIL3_HUMAN.H10MO.C' 'HO_NKX21_HUMAN.H10MO.D' 'HO_NR2E1_HUMAN.H10MO.D'
#  'HO_CEBPE_HUMAN.H10MO.A' 'HO_ERF_HUMAN.H10MO.D' 'HO_ZSC16_HUMAN.H10MO.D'
#  'HO_PRD14_HUMAN.H10MO.C' 'HO_GLI2_HUMAN.H10MO.B' 'HO_SOX17_HUMAN.H10MO.D'
#  'HO_OLIG1_HUMAN.H10MO.D' 'HO_ALX4_HUMAN.H10MO.D' 'HO_GLIS3_HUMAN.H10MO.D'
#  'HO_CXXC1_HUMAN.H10MO.D' 'HO_HLF_HUMAN.H10MO.C' 'HO_SCRT2_HUMAN.H10MO.D'
#  'HO_SCRT1_HUMAN.H10MO.D' 'HO_CUX2_HUMAN.H10MO.D' 'HO_SOX11_HUMAN.H10MO.D'
#  'HO_HOMEZ_HUMAN.H10MO.D' 'HO_PAX7_HUMAN.H10MO.D' 'HO_ANDR_HUMAN.H10MO.A'
#  'HO_PRGR_HUMAN.H10MO.C' 'HO_NR1D1_HUMAN.H10MO.C' 'HO_P63_HUMAN.H10MO.S'
#  'HO_HNF4A_HUMAN.H10MO.A' 'HO_MEIS2_HUMAN.H10MO.B' 'HO_HXB6_HUMAN.H10MO.D'
#  'HO_TBX21_HUMAN.H10MO.D' 'HO_TBR1_HUMAN.H10MO.D' 'HO_HSF4_HUMAN.H10MO.D'
#  'HO_HXB2_HUMAN.H10MO.D' 'HO_SOX18_HUMAN.H10MO.D' 'HO_FOXH1_HUMAN.H10MO.A'
#  'HO_HES1_HUMAN.H10MO.D' 'HO_GCM1_HUMAN.H10MO.D' 'HO_ETV3_HUMAN.H10MO.D'
#  'HO_HEY2_HUMAN.H10MO.D' 'HO_NKX32_HUMAN.H10MO.C' 'HO_TBX3_HUMAN.H10MO.D'
#  'HO_OLIG3_HUMAN.H10MO.D' 'HO_ZN652_HUMAN.H10MO.D' 'HO_PDX1_HUMAN.H10MO.C'
#  'HO_PBX1_HUMAN.H10MO.B' 'HO_HXC8_HUMAN.H10MO.D' 'HO_HXB8_HUMAN.H10MO.C'
#  'HO_DLX3_HUMAN.H10MO.C' 'HO_HNF1B_HUMAN.H10MO.B' 'HO_HTF4_HUMAN.H10MO.B'
#  'HO_ITF2_HUMAN.H10MO.B' 'HO_ALX1_HUMAN.H10MO.B' 'HO_ARX_HUMAN.H10MO.D'
#  'HO_SOX21_HUMAN.H10MO.D' 'HO_HXB1_HUMAN.H10MO.D' 'HO_SOX8_HUMAN.H10MO.D'
#  'HO_HXC13_HUMAN.H10MO.D' 'HO_HXA1_HUMAN.H10MO.C' 'HO_PO4F3_HUMAN.H10MO.D'
#  'HO_MSX1_HUMAN.H10MO.D' 'HO_MSX2_HUMAN.H10MO.D' 'HO_LHX3_HUMAN.H10MO.C'
#  'HO_PO4F1_HUMAN.H10MO.D' 'HO_CDC5L_HUMAN.H10MO.D' 'HO_PAX4_HUMAN.H10MO.D'
#  'HO_HXA5_HUMAN.H10MO.D' 'HO_VAX1_HUMAN.H10MO.D' 'HO_HES5_HUMAN.H10MO.D'
#  'HO_HES7_HUMAN.H10MO.D' 'HO_TBX4_HUMAN.H10MO.D' 'HO_BARX1_HUMAN.H10MO.D'
#  'HO_HEY1_HUMAN.H10MO.D' 'HO_BARH1_HUMAN.H10MO.D' 'HO_PHX2A_HUMAN.H10MO.D'
#  'HO_DRGX_HUMAN.H10MO.D' 'HO_DDIT3_HUMAN.H10MO.C' 'HO_TBX20_HUMAN.H10MO.D'
#  'HO_LHX6_HUMAN.H10MO.D' 'HO_NR6A1_HUMAN.H10MO.B' 'HO_ZN784_HUMAN.H10MO.D'
#  'HO_UBIP1_HUMAN.H10MO.D' 'HO_PPARA_HUMAN.H10MO.S' 'HO_PRRX1_HUMAN.H10MO.D'
#  'HO_NFIA_HUMAN.H10MO.S' 'HO_FOXO3_HUMAN.H10MO.B' 'HO_FOXA3_HUMAN.H10MO.C'
#  'HO_SRF_HUMAN.H10MO.A' 'HO_CPEB1_HUMAN.H10MO.D' 'HO_NR1I3_HUMAN.H10MO.S'
#  'HO_NR1I2_HUMAN.H10MO.S' 'HO_IRF3_HUMAN.H10MO.C' 'HO_AP2C_HUMAN.H10MO.A'
#  'HO_AP2A_HUMAN.H10MO.C' 'HO_MEF2D_HUMAN.H10MO.C' 'HO_PPARG_HUMAN.H10MO.S'
#  'HO_PO3F2_HUMAN.H10MO.D' 'HO_MZF1_HUMAN.H10MO.D' 'HO_REL_HUMAN.H10MO.C'
#  'HO_MYOD1_HUMAN.H10MO.C' 'HO_SMAD3_HUMAN.H10MO.C' 'HO_GCR_HUMAN.H10MO.S'
#  'HO_PRGR_HUMAN.H10MO.S' 'HO_IRF1_HUMAN.H10MO.A' 'HO_STAT2_HUMAN.H10MO.B'
#  'HO_SNAI1_HUMAN.H10MO.C' 'HO_PO3F4_HUMAN.H10MO.D' 'HO_PO2F3_HUMAN.H10MO.D'
#  'HO_P5F1B_HUMAN.H10MO.D' 'HO_EPAS1_HUMAN.H10MO.D' 'HO_TLX1_HUMAN.H10MO.D'
#  'HO_EOMES_HUMAN.H10MO.D' 'HO_KLF8_HUMAN.H10MO.C' 'HO_ZN740_HUMAN.H10MO.D'
#  'HO_CEBPB_HUMAN.H10MO.A' 'HO_CEBPD_HUMAN.H10MO.B' 'HO_PO5F1_HUMAN.H10MO.A'
#  'HO_FOXO6_HUMAN.H10MO.D' 'HO_LBX2_HUMAN.H10MO.D' 'HO_MYF6_HUMAN.H10MO.C'
#  'HO_TF65_HUMAN.H10MO.A' 'HO_IRF2_HUMAN.H10MO.C' 'HO_PRDM1_HUMAN.H10MO.C'
#  'HO_TFAP4_HUMAN.H10MO.C' 'HO_IRF7_HUMAN.H10MO.C' 'HO_OTX1_HUMAN.H10MO.D'
#  'HO_PLAG1_HUMAN.H10MO.D' 'HO_MAF_HUMAN.H10MO.B' 'HO_MECP2_HUMAN.H10MO.C'
#  'HO_MYCN_HUMAN.H10MO.B' 'HO_TWST1_HUMAN.H10MO.D' 'HO_STAT6_HUMAN.H10MO.C'
#  'HO_NDF1_HUMAN.H10MO.C' 'HO_SRBP1_HUMAN.H10MO.B' 'HO_P73_HUMAN.H10MO.S'
#  'HO_TFE2_HUMAN.H10MO.C' 'HO_MNT_HUMAN.H10MO.D' 'HO_IRF4_HUMAN.H10MO.C'
#  'HO_BC11A_HUMAN.H10MO.C' 'HO_ELF5_HUMAN.H10MO.D' 'HO_HXD8_HUMAN.H10MO.D'
#  'HO_FOXA1_HUMAN.H10MO.A' 'HO_GATA3_HUMAN.H10MO.C' 'HO_SRBP2_HUMAN.H10MO.B'
#  'HO_PO2F1_HUMAN.H10MO.B' 'HO_FOXP2_HUMAN.H10MO.A' 'HO_ASCL2_HUMAN.H10MO.D'
#  'HO_IRF8_HUMAN.H10MO.D' 'HO_RUNX2_HUMAN.H10MO.B' 'HO_EHF_HUMAN.H10MO.C'
#  'HO_NF2L1_HUMAN.H10MO.C' 'HO_ESR2_HUMAN.H10MO.S' 'HO_TGIF1_HUMAN.H10MO.S'
#  'HO_MYB_HUMAN.H10MO.C' 'HO_PAX2_HUMAN.H10MO.S' 'HO_SPIC_HUMAN.H10MO.D'
#  'HO_GATA6_HUMAN.H10MO.S' 'HO_FOXA2_HUMAN.H10MO.A' 'HO_GATA4_HUMAN.H10MO.B'
#  'HO_BCL6_HUMAN.H10MO.C' 'HO_KLF15_HUMAN.H10MO.D' 'HO_MAFG_HUMAN.H10MO.S'
#  'HO_MESP1_HUMAN.H10MO.D' 'HO_NKX25_HUMAN.H10MO.C' 'HO_AIRE_HUMAN.H10MO.C'
#  'HO_NANOG_HUMAN.H10MO.S' 'HO_HIC2_HUMAN.H10MO.D' 'HO_NR2E3_HUMAN.H10MO.C'
#  'HO_EMX1_HUMAN.H10MO.D' 'HO_EMX2_HUMAN.H10MO.D' 'HO_NKX28_HUMAN.H10MO.C'
#  'HO_FOXQ1_HUMAN.H10MO.C' 'HO_RFX5_HUMAN.H10MO.A' 'HO_CEBPG_HUMAN.H10MO.C'
#  'HO_CEBPA_HUMAN.H10MO.A' 'HO_HXA10_HUMAN.H10MO.C' 'HO_HXC6_HUMAN.H10MO.D'
#  'HO_PO6F2_HUMAN.H10MO.D' 'HO_OTX2_HUMAN.H10MO.C' 'HO_AP2D_HUMAN.H10MO.D'
#  'HO_TEAD1_HUMAN.H10MO.D' 'HO_MCR_HUMAN.H10MO.D' 'HO_HXA13_HUMAN.H10MO.C'
#  'HO_TF7L2_HUMAN.H10MO.A' 'HO_IRX2_HUMAN.H10MO.D' 'HO_ZN384_HUMAN.H10MO.C'
#  'HO_E2F8_HUMAN.H10MO.D' 'HO_PKNX2_HUMAN.H10MO.D' 'HO_ZIC1_HUMAN.H10MO.B'
#  'HO_ZIC2_HUMAN.H10MO.C' 'HO_LEF1_HUMAN.H10MO.C' 'HO_MAFA_HUMAN.H10MO.D'
#  'HO_HAND1_HUMAN.H10MO.D' 'HO_BHE23_HUMAN.H10MO.D' 'HO_NKX22_HUMAN.H10MO.D'
#  'HO_FOXB1_HUMAN.H10MO.D' 'HO_TEF_HUMAN.H10MO.D' 'HO_DBP_HUMAN.H10MO.B'
#  'HO_PO4F2_HUMAN.H10MO.D' 'HO_P53_HUMAN.H10MO.B' 'HO_LHX8_HUMAN.H10MO.D'
#  'HO_OLIG2_HUMAN.H10MO.D' 'HO_NGN2_HUMAN.H10MO.D' 'HO_ATOH1_HUMAN.H10MO.D'
#  'HO_BHA15_HUMAN.H10MO.D' 'HO_NR1I3_HUMAN.H10MO.C' 'HO_PTF1A_HUMAN.H10MO.C'
#  'HO_HSF2_HUMAN.H10MO.A' 'HO_PLAG1_HUMAN.H10MO.S' 'HO_RORG_HUMAN.H10MO.C'
#  'HO_MYBB_HUMAN.H10MO.D' 'HO_ERR3_HUMAN.H10MO.B' 'HO_HMBX1_HUMAN.H10MO.D'
#  'HO_DUXA_HUMAN.H10MO.D' 'HO_TLX1_HUMAN.H10MO.S' 'HO_OVOL1_HUMAN.H10MO.C'
#  'HO_MEIS3_HUMAN.H10MO.D' 'HO_HXD3_HUMAN.H10MO.D' 'HO_TGIF2_HUMAN.H10MO.D'
#  'HO_HME1_HUMAN.H10MO.D' 'HO_RXRA_HUMAN.H10MO.C' 'HO_NOBOX_HUMAN.H10MO.C'
#  'HO_SUH_HUMAN.H10MO.C' 'HO_SMAD1_HUMAN.H10MO.D' 'HO_COE1_HUMAN.H10MO.A'
#  'HO_HSF1_HUMAN.H10MO.A' 'HO_NR2F6_HUMAN.H10MO.D' 'HO_HLTF_HUMAN.H10MO.D'
#  'HO_ERR1_HUMAN.H10MO.D' 'HO_NANOG_HUMAN.H10MO.A' 'HO_IRF9_HUMAN.H10MO.C'
#  'HO_NR4A3_HUMAN.H10MO.D' 'HO_NR4A1_HUMAN.H10MO.C' 'HO_NR4A2_HUMAN.H10MO.C'
#  'HO_PKNX1_HUMAN.H10MO.D' 'HO_SOX2_HUMAN.H10MO.B' 'HO_HNF4G_HUMAN.H10MO.C'
#  'HO_GCR_HUMAN.H10MO.A' 'HO_NR1I2_HUMAN.H10MO.C' 'HO_MEOX1_HUMAN.H10MO.D'
#  'HO_ENOA_HUMAN.H10MO.A' 'HO_NFKB2_HUMAN.H10MO.D' 'HO_PPARD_HUMAN.H10MO.D'
#  'HO_NFAT5_HUMAN.H10MO.D' 'HO_BHE41_HUMAN.H10MO.D' 'HO_ESR1_HUMAN.H10MO.A'
#  'HO_RELB_HUMAN.H10MO.C' 'HO_MYOG_HUMAN.H10MO.D' 'HO_SOX4_HUMAN.H10MO.C'
#  'HO_THA_HUMAN.H10MO.C' 'HO_ID4_HUMAN.H10MO.D' 'HO_PITX2_HUMAN.H10MO.D'
#  'HO_TBX2_HUMAN.H10MO.D' 'HO_DLX2_HUMAN.H10MO.D' 'HO_NKX61_HUMAN.H10MO.D'
#  'HO_LMX1B_HUMAN.H10MO.D' 'HO_HMX2_HUMAN.H10MO.D' 'HO_PROP1_HUMAN.H10MO.D'
#  'HO_RAX2_HUMAN.H10MO.D' 'HO_ZKSC1_HUMAN.H10MO.C' 'HO_HXD13_HUMAN.H10MO.D'
#  'HO_NKX31_HUMAN.H10MO.C' 'HO_P73_HUMAN.H10MO.A' 'HO_MEOX2_HUMAN.H10MO.D'
#  'HO_FOXP3_HUMAN.H10MO.D' 'HO_DLX5_HUMAN.H10MO.D' 'HO_SOX5_HUMAN.H10MO.C'
#  'HO_HNF6_HUMAN.H10MO.C' 'HO_FOXD2_HUMAN.H10MO.D' 'HO_HMX1_HUMAN.H10MO.D'
#  'HO_BARX2_HUMAN.H10MO.D' 'HO_ZFHX3_HUMAN.H10MO.D' 'HO_RX_HUMAN.H10MO.D'
#  'HO_HXA2_HUMAN.H10MO.D' 'HO_BSH_HUMAN.H10MO.D' 'HO_ALX3_HUMAN.H10MO.D'
#  'HO_UNC4_HUMAN.H10MO.D' 'HO_PHX2B_HUMAN.H10MO.D' 'HO_SOX3_HUMAN.H10MO.D'
#  'HO_SOX9_HUMAN.H10MO.B' 'HO_HMX3_HUMAN.H10MO.D' 'HO_ZEB1_HUMAN.H10MO.B'
#  'HO_GFI1B_HUMAN.H10MO.C' 'HO_GFI1_HUMAN.H10MO.C' 'HO_ARI5B_HUMAN.H10MO.C'
#  'HO_HME2_HUMAN.H10MO.D' 'HO_MIXL1_HUMAN.H10MO.D' 'HO_NOTO_HUMAN.H10MO.D'
#  'HO_BHE22_HUMAN.H10MO.D' 'HO_PBX2_HUMAN.H10MO.C' 'HO_HXB7_HUMAN.H10MO.C'
#  'HO_HNF1A_HUMAN.H10MO.A' 'HO_BARH2_HUMAN.H10MO.D' 'HO_LHX2_HUMAN.H10MO.D'
#  'HO_FIGLA_HUMAN.H10MO.D' 'HO_HBP1_HUMAN.H10MO.D' 'HO_VENTX_HUMAN.H10MO.D'
#  'HO_RXRB_HUMAN.H10MO.C' 'HO_THA_HUMAN.H10MO.S' 'HO_HXA11_HUMAN.H10MO.D'
#  'HO_THB_HUMAN.H10MO.C' 'HO_IKZF1_HUMAN.H10MO.C' 'HO_HXC10_HUMAN.H10MO.D'
#  'HO_HMGA1_HUMAN.H10MO.D' 'HO_TBX5_HUMAN.H10MO.D' 'HO_HXD11_HUMAN.H10MO.D'
#  'HO_HXD12_HUMAN.H10MO.D' 'HO_ONEC3_HUMAN.H10MO.D' 'HO_ARI3A_HUMAN.H10MO.D'
#  'HO_LMX1A_HUMAN.H10MO.D' 'HO_DLX4_HUMAN.H10MO.D' 'HO_DLX6_HUMAN.H10MO.D'
#  'HO_FOXJ2_HUMAN.H10MO.C' 'HO_FOXG1_HUMAN.H10MO.D' 'HO_FOXF1_HUMAN.H10MO.D'
#  'HO_FOXJ3_HUMAN.H10MO.A' 'HO_FUBP1_HUMAN.H10MO.D' 'HO_FOXM1_HUMAN.H10MO.D'
#  'HO_FOXJ3_HUMAN.H10MO.S' 'HO_PAX5_HUMAN.H10MO.S' 'HO_MEF2C_HUMAN.H10MO.C'
#  'HO_HXD4_HUMAN.H10MO.D' 'HO_ARI3A_HUMAN.H10MO.S' 'HO_PRRX2_HUMAN.H10MO.C'
#  'HO_RARB_HUMAN.H10MO.D' 'HO_HXB13_HUMAN.H10MO.D' 'HO_IRX3_HUMAN.H10MO.D'
#  'HO_EVX2_HUMAN.H10MO.A' 'HO_EVX1_HUMAN.H10MO.D' 'HO_PO3F3_HUMAN.H10MO.D'
#  'HO_ONEC2_HUMAN.H10MO.D' 'HO_FOXL1_HUMAN.H10MO.D' 'HO_MNX1_HUMAN.H10MO.D'
#  'HO_HXD9_HUMAN.H10MO.D' 'HO_GBX2_HUMAN.H10MO.D' 'HO_LHX9_HUMAN.H10MO.D'
#  'HO_SHOX2_HUMAN.H10MO.D' 'HO_ISX_HUMAN.H10MO.D' 'HO_GBX1_HUMAN.H10MO.D'
#  'HO_GSX2_HUMAN.H10MO.D' 'HO_LHX4_HUMAN.H10MO.D' 'HO_DMBX1_HUMAN.H10MO.D'
#  'HO_SHOX_HUMAN.H10MO.D' 'HO_TBP_HUMAN.H10MO.C' 'HO_NKX62_HUMAN.H10MO.D'
#  'HO_HXB3_HUMAN.H10MO.D' 'HO_SOX15_HUMAN.H10MO.D' 'HO_RARA_HUMAN.H10MO.S'
#  'HO_RARG_HUMAN.H10MO.S' 'HO_ISL1_HUMAN.H10MO.D' 'HO_CDX1_HUMAN.H10MO.C'
#  'HO_CDX2_HUMAN.H10MO.C' 'HO_IRF5_HUMAN.H10MO.D' 'HO_ZN713_HUMAN.H10MO.D'
#  'HO_FOXO1_HUMAN.H10MO.C' 'HO_SRY_HUMAN.H10MO.B' 'HO_FOXD3_HUMAN.H10MO.D'
#  'HO_BPTF_HUMAN.H10MO.D' 'HO_SOX10_HUMAN.H10MO.D' 'HO_ETV2_HUMAN.H10MO.D'
#  'HO_NFAC1_HUMAN.H10MO.A' 'HO_NFAC4_HUMAN.H10MO.C' 'HO_HXC12_HUMAN.H10MO.D'
#  'HO_BRCA1_HUMAN.H10MO.D' 'HO_DLX1_HUMAN.H10MO.D' 'HO_TEAD4_HUMAN.H10MO.A'
#  'HO_CRX_HUMAN.H10MO.C' 'HO_FOXO4_HUMAN.H10MO.C' 'HO_ZN219_HUMAN.H10MO.D'
#  'HO_PAX5_HUMAN.H10MO.A' 'HO_GSX1_HUMAN.H10MO.D' 'HO_ISL2_HUMAN.H10MO.D'
#  'HO_MEF2A_HUMAN.H10MO.A' 'HO_ESX1_HUMAN.H10MO.D' 'HO_SNAI2_HUMAN.H10MO.C'
#  'HO_VDR_HUMAN.H10MO.S' 'HO_NFAC3_HUMAN.H10MO.B' 'HO_ERR2_HUMAN.H10MO.A'
#  'HO_NR5A2_HUMAN.H10MO.C' 'HO_STF1_HUMAN.H10MO.B' 'HO_PIT1_HUMAN.H10MO.C'
#  'HO_GATA5_HUMAN.H10MO.D' 'HO_SOX13_HUMAN.H10MO.D' 'HO_TEAD3_HUMAN.H10MO.D'
#  'HO_VSX1_HUMAN.H10MO.D' 'HO_ZKSC3_HUMAN.H10MO.D' 'HO_NR1H2_HUMAN.H10MO.D'
#  'HO_ZN524_HUMAN.H10MO.D' 'HO_TBX19_HUMAN.H10MO.D' 'HO_ZN232_HUMAN.H10MO.D'
#  'HO_CUX1_HUMAN.H10MO.C' 'HO_HMGA2_HUMAN.H10MO.D' 'HO_MGAP_HUMAN.H10MO.D'
#  'HO_SOX7_HUMAN.H10MO.D' 'HO_NFAC2_HUMAN.H10MO.B' 'HO_RORA_HUMAN.H10MO.B'
#  'HO_AHR_HUMAN.H10MO.B' 'HO_GMEB2_HUMAN.H10MO.D' 'HO_TF7L1_HUMAN.H10MO.D'
#  'HO_BCL6B_HUMAN.H10MO.D' 'HO_NR1H4_HUMAN.H10MO.C' 'HO_SPZ1_HUMAN.H10MO.D'
#  'HO_ZIC4_HUMAN.H10MO.D' 'HO_DPRX_HUMAN.H10MO.D' 'HO_MTF1_HUMAN.H10MO.C'
#  'HO_CR3L1_HUMAN.H10MO.D' 'HO_ATF6A_HUMAN.H10MO.B' 'HO_E2F7_HUMAN.H10MO.D'
#  'HO_HIF1A_HUMAN.H10MO.A' 'HO_ZBTB4_HUMAN.H10MO.S' 'HO_NFKB1_HUMAN.H10MO.B'
#  'HO_TCF7_HUMAN.H10MO.C' 'HO_PRDM4_HUMAN.H10MO.D' 'HO_GCM2_HUMAN.H10MO.D'
#  'HO_GLIS1_HUMAN.H10MO.D' 'HO_GLI3_HUMAN.H10MO.B' 'HO_RUNX1_HUMAN.H10MO.A'
#  'HO_RUNX3_HUMAN.H10MO.C' 'HO_ZIC3_HUMAN.H10MO.C' 'HO_PEBB_HUMAN.H10MO.C'
#  'HO_GLI1_HUMAN.H10MO.C' 'HO_HSFY1_HUMAN.H10MO.D' 'HO_BRAC_HUMAN.H10MO.D'
#  'HO_REST_HUMAN.H10MO.A' 'HO_PAX3_HUMAN.H10MO.D' 'HO_ZN423_HUMAN.H10MO.D'
#  'HO_PAX6_HUMAN.H10MO.D' 'HO_ZN143_HUMAN.H10MO.A' 'HO_RFX2_HUMAN.H10MO.C'
#  'HO_KLF12_HUMAN.H10MO.D' 'HO_RFX3_HUMAN.H10MO.B' 'HO_GSC2_HUMAN.H10MO.D'
#  'HO_MAFF_HUMAN.H10MO.A' 'HO_BHE40_HUMAN.H10MO.A' 'HO_MAFK_HUMAN.H10MO.A'
#  'HO_MAFG_HUMAN.H10MO.C' 'HO_EGR2_HUMAN.H10MO.C' 'HO_NRL_HUMAN.H10MO.D'
#  'HO_GATA1_HUMAN.H10MO.S' 'HO_GATA2_HUMAN.H10MO.A' 'HO_FLI1_HUMAN.H10MO.A'
#  'HO_ETS1_HUMAN.H10MO.C' 'HO_ELF1_HUMAN.H10MO.A' 'HO_WT1_HUMAN.H10MO.D'
#  'HO_TFDP1_HUMAN.H10MO.D' 'HO_KLF6_HUMAN.H10MO.D' 'HO_ZN148_HUMAN.H10MO.D'
#  'HO_MAZ_HUMAN.H10MO.A' 'HO_TFE3_HUMAN.H10MO.C' 'HO_TFDP1_HUMAN.H10MO.S'
#  'HO_E2F1_HUMAN.H10MO.A' 'HO_E2F4_HUMAN.H10MO.A' 'HO_MBD2_HUMAN.H10MO.B'
#  'HO_HXD10_HUMAN.H10MO.D' 'HO_GABP1_HUMAN.H10MO.C' 'HO_TYY2_HUMAN.H10MO.D'
#  'HO_ZBT7B_HUMAN.H10MO.D' 'HO_RFX4_HUMAN.H10MO.D' 'HO_CREM_HUMAN.H10MO.C'
#  'HO_KLF14_HUMAN.H10MO.D' 'HO_CR3L2_HUMAN.H10MO.D' 'HO_XBP1_HUMAN.H10MO.C'
#  'HO_MLX_HUMAN.H10MO.D' 'HO_THAP1_HUMAN.H10MO.D' 'HO_PAX2_HUMAN.H10MO.D'
#  'HO_PITX3_HUMAN.H10MO.D' 'HO_TBX1_HUMAN.H10MO.D' 'HO_MITF_HUMAN.H10MO.C'
#  'HO_KLF13_HUMAN.H10MO.D' 'HO_ETV1_HUMAN.H10MO.B' 'HO_KLF16_HUMAN.H10MO.D'
#  'HO_STAT3_HUMAN.H10MO.A' 'HO_ETV7_HUMAN.H10MO.D' 'HO_NFIA_HUMAN.H10MO.C'
#  'HO_CLOCK_HUMAN.H10MO.D' 'HO_ELF2_HUMAN.H10MO.C' 'HO_TBX15_HUMAN.H10MO.D'
#  'HO_STAT4_HUMAN.H10MO.D' 'HO_E2F6_HUMAN.H10MO.C' 'HO_KLF1_HUMAN.H10MO.C'
#  'HO_BATF_HUMAN.H10MO.A' 'HO_ETS2_HUMAN.H10MO.C' 'HO_EHF_HUMAN.H10MO.S'
#  'HO_EGR1_HUMAN.H10MO.A' 'HO_SPIB_HUMAN.H10MO.B' 'HO_ETV4_HUMAN.H10MO.B'
#  'HO_FEV_HUMAN.H10MO.C' 'HO_SPI1_HUMAN.H10MO.A' 'HO_PURA_HUMAN.H10MO.D'
#  'HO_STA5A_HUMAN.H10MO.B' 'HO_STA5B_HUMAN.H10MO.C' 'HO_NFIC_HUMAN.H10MO.A'
#  'HO_ELF3_HUMAN.H10MO.D' 'HO_ETV5_HUMAN.H10MO.D' 'HO_ZFX_HUMAN.H10MO.C'
#  'HO_PITX1_HUMAN.H10MO.D' 'HO_PROX1_HUMAN.H10MO.D' 'HO_RREB1_HUMAN.H10MO.D'
#  'HO_KLF3_HUMAN.H10MO.D' 'HO_PO2F2_HUMAN.H10MO.D' 'HO_ARNT_HUMAN.H10MO.B'
#  'HO_NR0B1_HUMAN.H10MO.D' 'HO_AP2B_HUMAN.H10MO.B' 'HO_ELK3_HUMAN.H10MO.D'
#  'HO_KAISO_HUMAN.H10MO.S' 'HO_TFCP2_HUMAN.H10MO.D']

# %%
'''
    promoter vs non-promoter associated motif dispalcements?
    
    and of course you can tss and comb with All, Spec and as_histogram=False methods !
'''


sns.set(font_scale=0.9)
sns.set_style("white")

F  = plt.figure(figsize=(15,6))
ax1 = F.add_subplot(1,3,1)
ax2 = F.add_subplot(1,3,2)
ax3 = F.add_subplot(1,3,3)
ax1.set_title("Promoter Associated Bidirectionals")
ax2.set_title("Non Promoter Associated Bidirectionals")
ax3.set_title("The Combination")




motif_order = d.show_motif_displacement(Spec="HO_FOS_HUMAN.H10MO.A",ax=ax1,as_histogram=True,tss=True)

motif_order = d.show_motif_displacement(Spec="HO_FOS_HUMAN.H10MO.A",ax=ax2,as_histogram=True, tss=False,comb=False)

motif_order = d.show_motif_displacement(Spec="HO_FOS_HUMAN.H10MO.A",ax=ax3,as_histogram=True, tss=False,comb=True)

# %%
'''
    can we quantify the peak from the noise in any meaningfuly way? Well the easiest attempt is the MD score 
    (described in our publication and used to assess if this peak has changed in any meaningful way) but we also
    developed a more advanced model: a uniform/laplace or uniform/gaussian mixture model which, when estimated 
    via the EM algorithm, can identify unimodal as well as bimodal peaks, see below for usage
    
    the core algorithm for this model fitting procedure is in
    
    normal_laplace.py (you can also toggle between normal or laplace components for modeling the peak)
'''
F  = plt.figure(figsize=(15,6))
ax1 = F.add_subplot(1,2,1)
ax2 = F.add_subplot(1,2,2)

M= "HO_NRF1_HUMAN.H10MO.A"
R = d.uni_bi(motif=M,norm=True) #gaussian
d.draw_density_function(R[0,0],R[0,1],R[0,2],ax=ax1)
d.show_motif_displacement(Spec=M,bins=200,ax=ax1,normed=1,as_histogram=True)

'''
    look at this motif displacement distribution!
'''

M2="HO_RUNX1_HUMAN.H10MO.A"
R = d.uni_bi(motif=M2,norm=False) #laplace
d.draw_density_function(R[0,0],R[0,1],R[0,2],ax=ax2)
d.show_motif_displacement(Spec=M2,bins=200,ax=ax2,normed=1,as_histogram=True)

# %% [markdown]
# # Differential Motif Displacement Analysis
# The question of this section concerns whether the motif displacement distributions have significantly changed between these two experiments. Perhaps the simplest solultion would be non-parameteric KS-test. Another is look at statistics of the data for which we know, under assumptions of the null model, how these statistics will behave. Examples the sample mean or a local proportion of motifs surrounding eRNAs. In any case, the anlysis package here allows for integration of these statistics.

# %%
'''
    lets take a look at a couple of datasets to see what I mean;
    the first dataset SRR639050 is a IMR90 GRO-seq experiment treated with DMSO (the control)
    the second dataset SRR639051 is a IMR90 GRO-seq experiment treated with TNFalpha (the treatment)
    well known activator of the NFKB1/REL family of transcription factors. 
'''


exp1 = dataset(MDS_DIR+"SRR639050" + ".csv")
exp2 = dataset(MDS_DIR+"SRR639051" + ".csv")

# %%
'''
    Lets look at the motif displacement distribution for NFKB1 surrounding eRNA origins before and after
'''
F  = plt.figure(figsize=(15,3))
ax1 = F.add_subplot(1,2,1)
ax2 = F.add_subplot(1,2,2)

ax1.set_title("Control (NFKB1)");ax2.set_title("Treatment (NFKB1)")
exp1.show_motif_displacement(Spec="HO_NFKB1_HUMAN.H10MO.B", as_histogram=False,ax=ax1,tss=0)
exp2.show_motif_displacement(Spec="HO_NFKB1_HUMAN.H10MO.B", as_histogram=False,ax=ax2,tss=0)

# %%
'''
    so obviosuly here is increase of motif events surrounding or proximal to eRNA localations. Can we quantify 
    this in any meaningful way? 
    
    Yes! And now we will use a different class which we call the mds_frame() 
    
    The mds_frame really only has two methods 
    
    1) load_MD_score_file() which takes any number .csv motif displacement files and a final string that is unique
        exerpiment identifier
    2) differential() which takes two strings (two of the unique experiment identifiers from one) to compare
        are returns of pandas dataframe
    
    Let me first just demonstrate use!
'''

md = mds_frame()
md.load_MD_score_file(MDS_DIR+"SRR639050" + ".csv", "control")
md.load_MD_score_file(MDS_DIR+"SRR639051" + ".csv", "TNFalpha")

# %%
'''
    now that we have loaded these datasets we can call differential on them 
    
    this will likely take about 10 secnonds, with time proportion to the number of replicates you provide
'''

df = md.differential("control", "TNFalpha")

# %%
'''
    now let's take a look at what is returned from this method
    
    we can first filter by some p-value cutoff
'''
dfs = df[df.pval_ks < pow(10,-5)]
dfu = df[df.pval_ks >= pow(10,-5)]


F   = plt.figure(figsize=(15,6))
ax1 = F.add_subplot(1,3,1)
ax2 = F.add_subplot(1,3,2)
ax3 = F.add_subplot(1,3,3)

'''
    now lets who how the local propotion of motifs chance between the two experiments
    as a function of the number of total motifs. In general, as the total number of motifs
    increases the relative variance (under a the normal model) should decrease as well
'''
ax1.scatter(dfs.counts, dfs.mds,edgecolor="white",color="red" )
ax1.scatter(dfu.counts, dfu.mds,edgecolor="white",color="blue" )


ax1.set_xscale("log");ax1.set_xlim(min(dfu.counts), max(dfu.counts) )
ax1.set_ylabel("Change in\nMotif Displacement Score")
ax1.set_xlabel("Total number of motif hits")

'''
    we can also just look at how the average distance to the eRNA origin changes
'''

ax2.scatter(dfs.counts, dfs.distance,edgecolor="white",color="red" )
ax2.scatter(dfu.counts, dfu.distance,edgecolor="white",color="blue" )
ax2.set_xscale("log");ax2.set_xlim(min(dfu.counts), max(dfu.counts) )
ax2.set_ylabel("Change in\nAverageDistance to eRNA origin")
ax2.set_ylim(-max(abs(dfs.distance) )-100,max(abs(dfs.distance) )+100 )
ax2.set_xlabel("Total number of motif hits")


ax3.hist(df.pval_ks,bins=100,edgecolor="white") 
ax3.set_xlabel("P-value")
ax3.set_ylabel("Frequency")

sns.despine(ax=ax1);sns.despine(ax=ax2);sns.despine(ax=ax3)
# Out:
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/figure.py:1595: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
